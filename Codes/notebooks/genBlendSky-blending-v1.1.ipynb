# %% [markdown]
# # Data-gen flux_ratio = 0.0005 n_ratio = 0.0005

# %%
from blending import genBlendSky

# %%
T1= genBlendSky(pix_arcsec=1, fov_deg=5, flux_ratio=0.0005, n_ratio=0.0005, beam=6, sep=6, auto=False, outdir = '../results/beam6_sep6/2_00005/')
# Out:
# Field of View: 5.00 deg
# Pixel Size: 1.00 arcsec
# Image Size: 18000
# Please simulate the blend sky manually!

# %%
T1._preprocessing()
# Out:
# +++++++++++ LOADING WILMAN DB +++++++++++
# Loading data from ../data/wilmandb_rqq.h5.
# Finish loading data
# Loading data from ../data/wilmandb_fr1.h5.
# Finish loading data
# Loading data from ../data/wilmandb_fr2.h5.
# Finish loading data
# Loading data from ../data/wilmandb_sf.h5.
# Finish loading data
# Loading data from ../data/wilmandb_sb.h5.
# Finish loading data
# Loading time: 58.325641301926225
# +++++++++++ LOADING HOSTS DB +++++++++++
# Loading time: 0.18899773387238383
# Host database have 4000 sources.
# +++++++++++ LOADING BLENDS DB +++++++++++
# Loading time: 0.013357566203922033
# Blend database have 2000 sources.
# [1544, 428] [147, 1007]
# tot_flux_s4000_151: 3.306122999000746
# tot_flux_sub200: 4.949966580938182e-05
# ratio: 1.4972118649046866e-05 33.395407271357044

# %%
len(T1.blend_host_indices)
# Out:
# 2

# %%
len(T1.blend_sub_indices)
# Out:
# 2

# %%
T1.simulate_blend_sky()
# Out:
# !!!=================== Inspecting pair # 1  ===================!!!
# 12568 12628 5336 5396
# !!!=================== Inspecting pair # 2  ===================!!!
# 16412 16472 13809 13869

# %%
T1.a_ratio
# Out:
# 0.05

# %%
T1.postprocessing()
# Out:
# Dumping time: 0.0008716252632439137
# Simulate low band of the idead sky.
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.00_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.0 MHz in time: 4.121124578174204
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.16_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.16 MHz in time: 3.7227622028440237
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.32_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.32 MHz in time: 4.024761856067926
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.48_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.48 MHz in time: 3.4253544001840055
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.64_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.64 MHz in time: 3.4146581129170954
# ../results/beam6_sep6/2_00005/ideal/Idealsky_120.80_n_pairs_2_f_ratio_00005_a_ratio_005.fits
# Done writing freq 120.8 MHz in time: 3.4551349938847125
# ...
